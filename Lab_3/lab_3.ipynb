# %%
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns 
import numpy as np

# %%
automobile_df = pd.read_csv("Automobile_data.csv")
automobile_df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
automobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
automobile_df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
automobile_df["normalized-losses"].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
automobile_df_copy = automobile_df.copy()
automobile_df_copy = automobile_df_copy.map(lambda x: np.nan if x == "?" else x)
automobile_df_copy.sample(5)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 140          2                83      subaru       gas        std
# 186          2                94  volkswagen       gas        std
# 102          0               108      nissan       gas        std
# 169          2               134      toyota       gas        std
# 81           3               153  mitsubishi       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 140          two  hatchback          4wd           front        93.3  ...
# 186         four      sedan          fwd           front        97.3  ...
# 102         four      wagon          fwd           front       100.4  ...
# 169          two  hatchback          rwd           front        98.4  ...
# 81           two  hatchback          fwd           front        96.3  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 140          108         2bbl  3.62    2.64               8.7         73
# 186          109         mpfi  3.19     3.4               9.0         85
# 102          181         mpfi  3.43    3.27               9.0        152
# 169          146         mpfi  3.62     3.5               9.3        116
# 81           122         2bbl  3.35    3.46               8.5         88
#
#      peak-rpm city-mpg highway-mpg  price
# 140      4400       26          31   7603
# 186      5250       27          34   8495
# 102      5200       17          22  14399
# 169      4800       24          30   9989
# 81       5000       25          32   8499
#
# [5 rows x 26 columns]

# %%
new_column_names = []

for old_name in automobile_df_copy.columns:
    new_name = old_name.replace("-", "_")
    new_column_names.append(new_name)

automobile_df_copy.columns = new_column_names
automobile_df_copy.sample(1)
# Out:
#      symboling normalized_losses    make fuel_type aspiration num_of_doors  \
# 112          0               161  peugot    diesel      turbo         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 112      sedan          rwd           front       107.9  ...          152
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 112          idi   3.7    3.52              21.0         95      4150
#
#     city_mpg highway_mpg  price
# 112       28          33  16900
#
# [1 rows x 26 columns]

# %%
automobile_df_copy.isna().sum()
# Out:
# symboling             0
# normalized_losses    41
# make                  0
# fuel_type             0
# aspiration            0
# num_of_doors          2
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
# def parse(x, gt, lt):
#     if pd.notna(x):
#         x = float(x)
#         if gt <= x <= lt:
#             return x
#     return np.nan


# numeric_attributes = [
#     ["symboling", -3, 3],
#     ["normalized_losses", 65, 256],
#     ["wheel_base", 86.6, 120.9],
#     ["length", 141.1, 208.1],
#     ["width", 86.6, 120.9],
#     ["height", 47.8, 59.8],
#     ["curb_weight", 1488, 4066],
#     ["engine_size", 61, 326],
#     ["bore", 2.54, 3.94],
#     ["stroke", 2.07, 4.17],
#     ["compression_ratio", 7, 23],
#     ["horsepower", 48, 288],
#     ["peak_rpm", 4150, 6600],
#     ["city_mpg", 13, 49],
#     ["highway_mpg", 16, 54],
#     ["price", 5118, 45400],
# ]

# for i in numeric_attributes:
#     automobile_df_copy[i[0]].apply(lambda x: parse(x, i[1], i[2]))

# automobile_df_copy.isna().sum()

# %%
automobile_df_copy["num_of_doors"].fillna("no info", inplace=True)
automobile_df_copy.fillna(0, inplace=True)
automobile_df_copy.isna().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
numeric_cols = ["normalized_losses", "bore", "stroke", "horsepower", "peak_rpm", "price"]

for i in numeric_cols:
    automobile_df_copy[i] = pd.to_numeric(automobile_df_copy[i])

automobile_df_copy.dtypes
# Out:
# symboling              int64
# normalized_losses      int64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower             int64
# peak_rpm               int64
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
figs, axes = plt.subplots(1, 2, figsize=(10, 5))
columns = ["fuel_type", "num_of_doors"]

for i, col in enumerate(columns):
    axes[i].set_title(f"К-сть авто за {col}")

    data_counts = (
        automobile_df_copy[[col, "price"]]
        .groupby(col, observed=True)
        .count()
        .reset_index()
    )
    axes[i].pie(
        x=data_counts["price"],
        labels=data_counts[col],
        autopct="%1.1f%%",
    )

plt.tight_layout(pad=2)

# %%
plt.figure(figsize=(12, 5))

sns.heatmap(
    data=automobile_df_copy.iloc[
        :, [0, 1, 9, 10, 11, 12, 13, 16, 18, 19, 20, 21, 22, 23, 24, 25]
    ].corr(),
    annot=True,
    cmap="Blues",
)

plt.title("Кореляція");

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=automobile_df_copy,
    x="price",
    y="symboling",
)

plt.ticklabel_format(style="plain", axis="y")
plt.title("Залежність ціни від фактору ризику")
plt.xlabel("Ціна")
plt.ylabel("Фактор ризику");

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=automobile_df_copy,
    x="price",
    y="horsepower",
    hue="fuel_type",
)

plt.ticklabel_format(style="plain", axis="y")
plt.title("Залежність ціни від к-сті кінських сил з поділом на тип пального")
plt.xlabel("Ціна")
plt.ylabel("К-сть кінських сил")
plt.legend(title="Тип пального");

# %%
figs, axes = plt.subplots(2, 2, figsize=(12, 6))
axes = axes.flatten()

columns = ["wheel_base", "length", "width", "curb_weight"]

for i, col in enumerate(columns):
        axes[i].set_title(f"Залежність ціни від {columns[i]} з поділом на тип пального")
        axes[i].set_ylabel(columns[i])
        axes[i].set_xlabel("Ціна")
        sns.scatterplot(
            data=automobile_df_copy,
            x="price",
            y=col,
            hue="fuel_type",
            ax=axes[i],
        )

plt.tight_layout(pad=2)

# %%
figs, axes = plt.subplots(1, 2, figsize=(12, 6))
axes = axes.flatten()

columns = ["city_mpg", "highway_mpg"]

for i, col in enumerate(columns):
        axes[i].set_title(f"Залежність ціни від {columns[i]} з поділом на тип пального")
        axes[i].set_ylabel(columns[i])
        axes[i].set_xlabel("Ціна")
        sns.scatterplot(
            data=automobile_df_copy,
            x="price",
            y=col,
            hue="fuel_type",
            ax=axes[i],
        )

plt.tight_layout(pad=2)

# %%
from sklearn.feature_selection import VarianceThreshold

set = np.array(
    automobile_df_copy[
        ["price", "wheel_base", "length", "width", "horsepower"]
    ].corr()
)
print(set)

selector = VarianceThreshold()
selector.fit(set)
print(set)
# Out:
# [[1.         0.57880396 0.68501879 0.6956545  0.69128788]
#  [0.57880396 1.         0.87458748 0.79514364 0.35168084]
#  [0.68501879 0.87458748 1.         0.84111827 0.52625311]
#  [0.6956545  0.79514364 0.84111827 1.         0.6140474 ]
#  [0.69128788 0.35168084 0.52625311 0.6140474  1.        ]]
# [[1.         0.57880396 0.68501879 0.6956545  0.69128788]
#  [0.57880396 1.         0.87458748 0.79514364 0.35168084]
#  [0.68501879 0.87458748 1.         0.84111827 0.52625311]
#  [0.6956545  0.79514364 0.84111827 1.         0.6140474 ]
#  [0.69128788 0.35168084 0.52625311 0.6140474  1.        ]]

# %%
from scipy.stats import pearsonr

X, y = (
    automobile_df_copy.iloc[
        :, [0, 1, 9, 10, 11, 12, 13, 16, 18, 19, 20, 21, 22, 23, 24, 25]
    ],
    automobile_df_copy.price,
)

for idx in X.columns:
    pea_score, p_value = pearsonr(X[idx], y)
    print(
        f"The absolute value of the correlation between the {idx} feature and price is {round(np.abs(pea_score),2)},p-value is {round(p_value,3)}"
    )


def udf_pearsonr(X1, y1):
    result = [pearsonr(X1[column], y1)[0] for column in X1.columns]
    return result


sns.set(font_scale=1.4)

data = np.round(
    pd.DataFrame(
        X.apply(lambda column: udf_pearsonr(X, column)).values.tolist(),
        columns=X.columns,
        index=X.columns,
    ),
    1,
)
# Out:
# The absolute value of the correlation between the symboling feature and price is 0.07,p-value is 0.309
# The absolute value of the correlation between the normalized_losses feature and price is 0.24,p-value is 0.001
# The absolute value of the correlation between the wheel_base feature and price is 0.58,p-value is 0.0
# The absolute value of the correlation between the length feature and price is 0.69,p-value is 0.0
# The absolute value of the correlation between the width feature and price is 0.7,p-value is 0.0
# The absolute value of the correlation between the height feature and price is 0.16,p-value is 0.023
# The absolute value of the correlation between the curb_weight feature and price is 0.8,p-value is 0.0
# The absolute value of the correlation between the engine_size feature and price is 0.84,p-value is 0.0
# The absolute value of the correlation between the bore feature and price is 0.26,p-value is 0.0
# The absolute value of the correlation between the stroke feature and price is 0.05,p-value is 0.487
# The absolute value of the correlation between the compression_ratio feature and price is 0.08,p-value is 0.267
# The absolute value of the correlation between the horsepower feature and price is 0.69,p-value is 0.0
# The absolute value of the correlation between the peak_rpm feature and price is 0.06,p-value is 0.431
# The absolute value of the correlation between the city_mpg feature and price is 0.66,p-value is 0.0
# The absolute value of the correlation between the highway_mpg feature and price is 0.69,p-value is 0.0
# The absolute value of the correlation between the price feature and price is 1.0,p-value is 0.0

# %%
plt.figure(figsize=(12, 6))

sns.heatmap(
    data=data,
    annot=True,
    cmap="Blues",
);

# %%
from sklearn.feature_selection import f_regression

for idx in X.columns:
    score, p_value = f_regression(X[idx].to_numpy().reshape(-1,1), y)
    print(f"The F-Score between the {idx} feature and price is {round(score[0],2)}, p-value is {round(p_value[0],3)}")
# Out:
# The F-Score between the symboling feature and price is 1.04, p-value is 0.309
# The F-Score between the normalized_losses feature and price is 12.18, p-value is 0.001
# The F-Score between the wheel_base feature and price is 102.27, p-value is 0.0
# The F-Score between the length feature and price is 179.48, p-value is 0.0
# The F-Score between the width feature and price is 190.36, p-value is 0.0
# The F-Score between the height feature and price is 5.23, p-value is 0.023
# The F-Score between the curb_weight feature and price is 360.32, p-value is 0.0
# The F-Score between the engine_size feature and price is 479.14, p-value is 0.0
# The F-Score between the bore feature and price is 15.22, p-value is 0.0
# The F-Score between the stroke feature and price is 0.49, p-value is 0.487
# The F-Score between the compression_ratio feature and price is 1.24, p-value is 0.267
# The F-Score between the horsepower feature and price is 185.8, p-value is 0.0
# The F-Score between the peak_rpm feature and price is 0.62, p-value is 0.431
# The F-Score between the city_mpg feature and price is 156.7, p-value is 0.0
# The F-Score between the highway_mpg feature and price is 182.12, p-value is 0.0
# The F-Score between the price feature and price is 4.5711536217810515e+17, p-value is 0.0

# %%
from sklearn.feature_selection import chi2

X = X > X.mean(0)

for idx in X.columns:
    score, p_value = chi2(X[idx].to_numpy().reshape(-1,1), y)
    print(f"The chi-square statistics between the {idx} feature and price is {round(score[0],2)}, p-value is {round(p_value[0],3)}")
# Out:
# The chi-square statistics between the symboling feature and price is 85.65, p-value is 1.0
# The chi-square statistics between the normalized_losses feature and price is 86.43, p-value is 1.0
# The chi-square statistics between the wheel_base feature and price is 120.52, p-value is 1.0
# The chi-square statistics between the length feature and price is 108.69, p-value is 1.0
# The chi-square statistics between the width feature and price is 113.29, p-value is 1.0
# The chi-square statistics between the height feature and price is 95.13, p-value is 1.0
# The chi-square statistics between the curb_weight feature and price is 117.34, p-value is 1.0
# The chi-square statistics between the engine_size feature and price is 125.9, p-value is 1.0
# The chi-square statistics between the bore feature and price is 87.05, p-value is 1.0
# The chi-square statistics between the stroke feature and price is 75.49, p-value is 1.0
# The chi-square statistics between the compression_ratio feature and price is 174.24, p-value is 0.722
# The chi-square statistics between the horsepower feature and price is 121.47, p-value is 1.0
# The chi-square statistics between the peak_rpm feature and price is 96.08, p-value is 1.0
# The chi-square statistics between the city_mpg feature and price is 109.8, p-value is 1.0
# The chi-square statistics between the highway_mpg feature and price is 104.91, p-value is 1.0
# The chi-square statistics between the price feature and price is 129.0, p-value is 1.0
